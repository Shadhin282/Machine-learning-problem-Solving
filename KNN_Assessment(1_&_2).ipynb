# %% [markdown]
# <a href="https://colab.research.google.com/github/Shadhin282/Machine-learning-problem-Solving/blob/main/KNN_Assessment(1_%26_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv('/weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.Gender = le.fit_transform(df[['Gender']])

# %%
df.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
df.tail()
# Out:
#       Gender     Height      Weight
# 8550       0  60.483946  110.565497
# 8551       0  63.423372  129.921671
# 8552       0  65.584057  155.942671
# 8553       0  67.429971  151.678405
# 8554       0  60.921791  131.253738

# %% [markdown]
# # Go Ahead

# %%
x = df.drop(columns=['Weight'])
y = df[['Weight']]
x.head()
# Out:
#    Gender     Height
# 0       1  73.847017
# 1       1  68.781904
# 2       1  74.110105
# 3       1  71.730978
# 4       1  69.881796

# %%
y.head()
# Out:
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=0)

# %%
xtrain.shape
# Out:
# (5988, 2)

# %%
ytrain.shape
# Out:
# (5988, 1)

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtest,ytest)
# Out:
# 0.9025307579174771

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.8988118427483529

# %%
from sklearn.metrics import mean_squared_error

# %%
predict = lr.predict(xtest)
predict[0:5]
# Out:
# array([[156.20235428],
#        [184.93442898],
#        [148.42945323],
#        [150.77947019],
#        [176.60175571]])

# %%
ytest.head()
# Out:
#           Weight
# 541   174.473363
# 3209  178.507500
# 7598  155.248900
# 5170  138.839940
# 2423  154.718344

# %%
mean_squared_error(ytest,predict)
# Out:
# 102.30154155088874

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,predict)
# Out:
# 0.9025307579174771

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors = 21)
knn
# Out:
# KNeighborsRegressor(n_neighbors=21)

# %%
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=21)

# %%
knn.score(xtest,ytest)
# Out:
# 0.8963739079210189

# %%
knn.kneighbors_graph(xtest)
# Out:
# <2567x5988 sparse matrix of type '<class 'numpy.float64'>'
# 	with 53907 stored elements in Compressed Sparse Row format>

# %%
knn.predict(xtest)[0:10]
# Out:
# array([[155.93093662],
#        [187.30392565],
#        [150.75798316],
#        [150.66758425],
#        [182.66808951],
#        [130.20444529],
#        [168.97974454],
#        [157.5318055 ],
#        [137.77646853],
#        [184.83200425]])

# %%
ytest.head(10)
# Out:
#           Weight
# 541   174.473363
# 3209  178.507500
# 7598  155.248900
# 5170  138.839940
# 2423  154.718344
# 6606  119.937293
# 4097  181.987816
# 4250  161.015155
# 7193  120.607958
# 3429  184.532866

# %% [markdown]
# Evaluating The results

# %%
knn.score(xtrain,ytrain)
# Out:
# 0.9028654156028769

# %%
knn.score(xtest,ytest)
# Out:
# 0.8963739079210189

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.8988118427483529

# %%
lr.score(xtest,ytest)
# Out:
# 0.9025307579174771

# %%
mean_squared_error(ytest,predict)
# Out:
# 102.30154155088874

# %%
mean_squared_error(ytest,knn.predict(xtest))
# Out:
# 108.76363392257245

# %%
r2_score(ytest,predict)
# Out:
# 0.9025307579174771

# %%
r2_score(ytest,knn.predict(xtest))
# Out:
# 0.8963739079210189

# %%
# More error shown at KNN regression model

# %% [markdown]
# Work with KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knnc = KNeighborsClassifier(n_neighbors =21)
knnc
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
x_c = df.drop(columns=['Gender'])
x_c.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
y_c = df[['Gender']]
y_c.head()
# Out:
#    Gender
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
x_train,x_test,y_train,y_test = train_test_split(x_c,y_c,test_size=0.30,random_state=0)

# %%
knnc.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
knnc.score(x_test,y_test)
# Out:
# 0.9146864043630697

# %%
knnc.predict(x_test)[0:10]
# Out:
# array([1, 1, 0, 0, 0, 0, 1, 1, 0, 1])

# %%
y_test.head(10)
# Out:
#       Gender
# 541        1
# 3209       1
# 7598       0
# 5170       0
# 2423       1
# 6606       0
# 4097       1
# 4250       1
# 7193       0
# 3429       1

# %%
mean_squared_error(y_test,knnc.predict(x_test))
# Out:
# 0.08531359563693026

# %%
r2_score(y_test,knnc.predict(x_test))
# Out:
# 0.6488464219592087

# %%
mean_squared_error(y_train,knnc.predict(x_train))
# Out:
# 0.07798931195724783

# %%
r2_score(y_train,knnc.predict(x_train))
# Out:
# 0.6788331026565217
